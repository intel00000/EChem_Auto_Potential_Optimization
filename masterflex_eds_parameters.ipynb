# %%
import pandas as pd
import json

# Load the JSON file
with open('masterflex_eds_parameters.json', 'r') as file:
    data = json.load(file)

# Convert JSON data to a Pandas DataFrame
df = pd.json_normalize(data, 'parameters')

# Display the DataFrame
df[:29]
# Out:
#        path descriptor data_type  data_size_bytes  \
# 0    Param1     0x0230      0xC1                1
# 1    Param2     0x0230      0xC1                1
# 2    Param3     0x0230      0xC1                1
# 3    Param4     0x0230      0xC1                1
# 4    Param5     0x0230      0xC1                1
# 5    Param7     0x0230      0xC1                1
# 6    Param8     0x0230      0xC1                1
# 7   Param33     0x0230      0xC2                1
# 8   Param34     0x0230      0xC2                1
# 9   Param35     0x0230      0xC2                1
# 10  Param36     0x0230      0xCA                4
# 11  Param37     0x0230      0xCA                4
# 12  Param38     0x0230      0xCA                4
# 13  Param39     0x0230      0xCA                4
# 14  Param40     0x0230      0xC4                4
# 15  Param41     0x0230      0xC4                4
# 16  Param42     0x0230      0xCA                4
# 17  Param43     0x0230      0xCA                4
# ...

# %%
# display an image name masterflex_eds_parameters.png
# compare with the eds information
from IPython.display import Image
Image(filename='masterflex_input_manual.png')
