# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse("241220 Gamry Framework AutoScreen Sequence.GSequence")
root = tree.getroot()

# Initialize containers
elements_list = []  # List to store XML element objects
parsed_elements = []  # List to store parsed dictionaries

# %%
# Extract <element> blocks
for element in root.findall(".//element"):
    # Store the element object in the list
    elements_list.append(element)

    # Parse the <element> block into a dictionary
    element_dict = {}
    for subelement in element:
        if subelement.tag == "parameters":  # Handle nested <parameters> separately
            element_dict["parameters"] = []
            for param in subelement:
                param_data = {key: value for key, value in param.attrib.items()}
                element_dict["parameters"].append(param_data)
        else:  # For other direct sub-elements, store their text
            element_dict[subelement.tag] = (
                subelement.text.strip() if subelement.text else None
            )

    # Add the parsed dictionary to the list
    parsed_elements.append(element_dict)

# Output the results
print("List of parsed dictionaries:")
for item in parsed_elements:
    print(item)
    print()
# Out:
# List of parsed dictionaries:
# {'name': 'Wait for Digital In', 'classname': 'WAITDIGITALIN', 'type': 'normal', 'description': "Wait for one or more digital in's of the potentiostat", 'parameters': [{'tag': 'DIGIN0', 'desc': 'Digital In 0:', 'item0': 'Low', 'item1': 'High', 'index': '0'}, {'tag': 'DIGIN1', 'desc': 'Digital In 1:', 'item0': 'Low', 'item1': 'High', 'index': '0'}, {'tag': 'DIGIN2', 'desc': 'Digital In 2:', 'item0': 'Low', 'item1': 'High', 'index': '0'}, {'tag': 'DIGIN3', 'desc': 'Digital In 3:', 'item0': 'Low', 'item1': 'High', 'index': '0'}], 'usecount': '0'}
#
# ...

# %%
print("\nList of XML element objects:")
for obj in elements_list:
    print(ET.tostring(obj, encoding="unicode"))
    print()
# Out:
# List of XML element objects:
# <element>
#     <name>Wait for Digital In</name>
#     <classname>WAITDIGITALIN</classname>
#     <type>normal</type>
#     <description>Wait for one or more digital in's of the potentiostat</description>
#     <parameters>
#       <explain_selector tag="DIGIN0" desc="Digital In 0:" item0="Low" item1="High" index="0" />
#       <explain_selector tag="DIGIN1" desc="Digital In 1:" item0="Low" item1="High" index="0" />
#       <explain_selector tag="DIGIN2" desc="Digital In 2:" item0="Low" item1="High" index="0" />
#       <explain_selector tag="DIGIN3" desc="Digital In 3:" item0="Low" item1="High" index="0" />
#     </parameters>
#     <usecount>0</usecount>
#   </element>
#
# <element>
#     <name>Group Data Files</name>
#     <classname>GROUPDATAFILES</classname>
#     <type>normal</type>
#     <description>Allows data files generated by the sequencer to be grouped together</description>
#     <parameters>
# ...

# %%
# grep all the tag with name element
for element in root.iter():
    print(f"tag: {element.tag}, attrib: {element.attrib}, element.
# Out:
#   Cell In[20], line 3
#     print(f"tag: {element.tag}, attrib: {element.attrib}, element.
#           ^
# SyntaxError: unterminated string literal (detected at line 3)
